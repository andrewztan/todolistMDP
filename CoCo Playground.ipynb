# %%
from todolist import *
from mdp_backward_induction import *
import matplotlib.pyplot as plt

# %%
# 2 tasks
goals1 = [
    Goal("Goal A", [
        Task("Task A1", 1)], 
        {1: 100},
        penalty=-1000),
    Goal("Goal B", [
        Task("Task B2", 1)], 
        {1: 10},
        penalty=-1000000)
]

# 4 tasks
goals2 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 1),  
        Task("Task B2", 1)], 
        {1: 10, 10: 10},
        penalty=0)
]

# 8 tasks
goals3 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
]

# 10 tasks
goals4 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
]

# 12 tasks
goals5 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal F", [
        Task("Task F1", 3),  
        Task("Task F2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
]

# 14 tasks
goals6 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal F", [
        Task("Task F1", 3),  
        Task("Task F2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal G", [
        Task("Task G1", 3),  
        Task("Task G2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
]

# 18 tasks
goals7 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal F", [
        Task("Task F1", 3),  
        Task("Task F2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal G", [
        Task("Task G1", 3),  
        Task("Task G2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal H", [
        Task("Task H1", 1),  
        Task("Task H2", 7)], 
        {50: 10, 70: 5},
        penalty=-110),
    Goal("Goal I", [
        Task("Task I1", 3),  
        Task("Task I2", 3)], 
        {60: 100, 70: 10},
        penalty=-10),
]

# 22 tasks
goals8 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal F", [
        Task("Task F1", 3),  
        Task("Task F2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal G", [
        Task("Task G1", 3),  
        Task("Task G2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal H", [
        Task("Task H1", 1),  
        Task("Task H2", 7)], 
        {50: 10, 70: 5},
        penalty=-110),
    Goal("Goal I", [
        Task("Task I1", 3),  
        Task("Task I2", 3)], 
        {60: 100, 70: 10},
        penalty=-10),
    Goal("Goal J", [
        Task("Task J1", 3),  
        Task("Task J2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal K", [
        Task("Task K1", 1),  
        Task("Task K2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
]

# 26 tasks
goals9 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal F", [
        Task("Task F1", 3),  
        Task("Task F2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal G", [
        Task("Task G1", 3),  
        Task("Task G2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal H", [
        Task("Task H1", 1),  
        Task("Task H2", 7)], 
        {50: 10, 70: 5},
        penalty=-110),
    Goal("Goal I", [
        Task("Task I1", 3),  
        Task("Task I2", 3)], 
        {60: 100, 70: 10},
        penalty=-10),
    Goal("Goal J", [
        Task("Task J1", 3),  
        Task("Task J2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal K", [
        Task("Task K1", 1),  
        Task("Task K2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal L", [
        Task("Task L1", 3),  
        Task("Task L2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal M", [
        Task("Task M1", 1),  
        Task("Task M2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
]

# 32 tasks
goals10 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal F", [
        Task("Task F1", 3),  
        Task("Task F2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal G", [
        Task("Task G1", 3),  
        Task("Task G2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal H", [
        Task("Task H1", 1),  
        Task("Task H2", 7)], 
        {50: 10, 70: 5},
        penalty=-110),
    Goal("Goal I", [
        Task("Task I1", 3),  
        Task("Task I2", 3)], 
        {60: 100, 70: 10},
        penalty=-10),
    Goal("Goal J", [
        Task("Task J1", 3),  
        Task("Task J2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal K", [
        Task("Task K1", 1),  
        Task("Task K2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal L", [
        Task("Task L1", 3),  
        Task("Task L2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal M", [
        Task("Task M1", 1),  
        Task("Task M2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal N", [
        Task("Task N1", 1),  
        Task("Task N2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal O", [
        Task("Task O1", 3),  
        Task("Task O2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal P", [
        Task("Task P1", 1),  
        Task("Task P2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
]

# 40 tasks
goals11 = [
    Goal("Goal A", [
        Task("Task A1", 1), 
        Task("Task A2", 1)], 
        {10: 100},
        penalty=-10),
    Goal("Goal B", [
        Task("Task B1", 2),  
        Task("Task B2", 2)], 
        {1: 10, 10: 10},
        penalty=0),
    Goal("Goal C", [
        Task("Task C1", 3),  
        Task("Task C2", 3)], 
        {1: 10, 6: 100},
        penalty=-1), 
    Goal("Goal D", [
        Task("Task D1", 3),  
        Task("Task D2", 3)], 
        {20: 100, 40: 10},
        penalty=-10),
    Goal("Goal E", [
        Task("Task E1", 3),  
        Task("Task E2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal F", [
        Task("Task F1", 3),  
        Task("Task F2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal G", [
        Task("Task G1", 3),  
        Task("Task G2", 3)], 
        {60: 100, 70: 10},
        penalty=-110),
    Goal("Goal H", [
        Task("Task H1", 1),  
        Task("Task H2", 7)], 
        {50: 10, 70: 5},
        penalty=-110),
    Goal("Goal I", [
        Task("Task I1", 3),  
        Task("Task I2", 3)], 
        {60: 100, 70: 10},
        penalty=-10),
    Goal("Goal J", [
        Task("Task J1", 3),  
        Task("Task J2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal K", [
        Task("Task K1", 1),  
        Task("Task K2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal L", [
        Task("Task L1", 3),  
        Task("Task L2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal M", [
        Task("Task M1", 1),  
        Task("Task M2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal N", [
        Task("Task N1", 1),  
        Task("Task N2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal O", [
        Task("Task O1", 3),  
        Task("Task O2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal P", [
        Task("Task P1", 1),  
        Task("Task P2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal Q", [
        Task("Task Q1", 1),  
        Task("Task Q2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal R", [
        Task("Task R1", 1),  
        Task("Task R2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
    Goal("Goal S", [
        Task("Task S1", 3),  
        Task("Task S2", 3)], 
        {60: 100, 70: 10},
        penalty=-1100),
    Goal("Goal T", [
        Task("Task T1", 1),  
        Task("Task T2", 7)], 
        {50: 10, 70: 5},
        penalty=-120),
]

# %%
# plotting number of tasks vs runtime with time kept constant at 500

end_time = 100
goals_list = [goals1, goals2, goals3, goals4, goals5, goals6, goals7, goals8, goals9, goals10, goals11]
goals_list = [goals7]
times = []

for i in range(len(goals_list)):
    goals = goals_list[i]
    print('goals', i)
    todolist = ToDoList(goals, start_time=0, end_time=end_time)
    start = time.time()
    mdp = ToDoListMDP(todolist)
    end = time.time()
    print('done building mdp', end - start)
    bi_policy, bi_iterations, bi_time_elapsed = backward_induction(mdp)
    times.append(bi_time_elapsed)
    
    print('time', bi_time_elapsed)
    print('policy', bi_policy)
    print()
    

# run with backward induction
# print 'backward induction'
# bi_policy, bi_iterations, bi_time_elapsed = backward_induction(mdp)
# print 'policy', bi_policy
# print 'time (s)', bi_time_elapsed
# print ''

# run with value iteration
# print 'value iteration'
# vi_policy, vi_iterations, vi_time_elapsed = value_iteration(mdp)
# print 'policy', vi_policy
# print 'time (s)', vi_time_elapsed
# print ''

# run with policy iteration
# print 'policy iteration'
# pi_policy, pi_iterations, pi_time_elapsed = policy_iteration(mdp)
# print 'policy', pi_policy
# print 'time (s)', pi_time_elapsed
# Out:
# goals 0

# %%
plt.clf()
plt.scatter([2, 4, 8, 10, 12, 14, 18, 22], times, color="navy", label="training set")
plt.xlabel('Num Tasks')
plt.ylabel('Seconds')
plt.ylim([-0.05, 14000])
plt.title("Runtime for Backward Induction w endtime = 100")
plt.show()

# %%
# Out:
# -------------------------------------------------------------------
# ImportError                       Traceback (most recent call last)
# <ipython-input-7-a48a553f7f9a> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import plotly.plotly as py
#       3 import numpy as np
#       4
#       5 # Learn about API authentication here: https://plot.ly/python/getting-started
#
# ImportError: No module named 'plotly'
